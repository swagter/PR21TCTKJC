# %% [markdown]
# ## Preučimo podatke o COVID-u
#
# Podatkovno rudarjenje, naloga, `12.4.2022`
#
# **`Člani: Tomaž Čuk, Tim Kuhar & Jorg Cimperman (Vodja).`**
#
# ##### Priprava podatkov
# Prebrali smo podatke iz ".csv" datotek in pripravili podatke v pravilni obliki. ".csv" datoteke smo pridobili s strani:
# https://covid-19.sledilnik.org/sl/stats
#
# # 1.1. vprašanje: Koliko okužb je glede na cepljenost?
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/avatars/designerauge/4rLyVYoSfDJ3.gif" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
#
# <span style="align:left; text-align:center;"><b>Glavno vprašanje</b>, ki se poraja vsakemu Slovencu je seveda, ali je cepivo učinkovito. Zato smo se odločili, da kot prvo vprašanje postavimo, koliko okužb imamo dnevno glede na (pre)cepljenost.</span>
# </div>
#
# <img src="podatki/images/graphs/g1.png" />
# <img src="podatki/images/graphs/g2.png" />
# <img src="podatki/images/graphs/g3.png" />
#
# **ODGOVOR**
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
#
# <span style="align:left; text-align:center;">Kot lahko razberemo iz grafov je cepivo pri 1. in 2. odmerku učinkovalo nekaj časa, potem pri zadnjem valu nekaj mesecev nazaj pa ni imelo učinka. Kot vidimo, se oblika grafa ponavlja. Domnevamo, da se z večjo precepljenostjo ljudje razvadijo in ne upoštevajo glavnih preventiv. Tako se okuži več ljudi in zgodi se skok (spike). Nato pa okužbe padejo, saj ljudje začasno postanejo imuni, saj so preboleli ali pa so cepljeni.
# </br></br>
# Domnevamo, da je morda razlog nova različica Omicron, ki naj bi bila bolj odporna na cepivo.
# Pri tretjem odmerku pa ni bilo tako prepoznavnega učinka. Tu pa vemo da 3. odmerek samo podaljša trajanje cepiva in ni toliko različen od 2. odmerka, zato menimo, da so ljudje, ki so že bili cepljeni 2x ostali "imuni" na virus in se tako kot po 2. cepljenju tudi po 3. niso okužili.</span>
# </div>
#
# # 1.2. vprašanje: Koliko okužb je glede na oceno zaščitenosti?
#
# <img src="podatki/images/graphs/g4.png" />
# <img src="podatki/images/graphs/g5.png" />
#
# **ODGOVOR**
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
#
# <span style="align:left; text-align:center;">Kot lahko razberemo iz grafov, ocena zaščitenosti in okužbe niso v direktni korelaciji. Celotna zaščitenost ne vpliva na okužbe.
# </br></br>
# Domnevamo, da je morda razlog ta, da je oseba lahko še vedno kužna ne glede na to ali je bila cepljena.</span>
# </div>
#
# ## 2.1 Koliko oseb je v bolnišnici glede na število okužb?
#
# <div style="display: flex; align-items: center">
# <img src="https://media4.giphy.com/media/feP0faKTehLA93yhFU/giphy.gif?cid=790b76117e13f9ed6a477a2bff16cbdf4e4360d21aa0edaf&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
#
# <span style="align:left; text-align:center;">Zanimalo nas je tudi, koliko oseb pravzaprav pristane na intenzivni negi z večanjem okužb. Seveda vemo, da se bo ta številka večala, vendar v kakšni meri se to dogaja?</span>
# </div>
#
# <img src="podatki/images/graphs/g7.png" />
#
# **ODGOVOR**
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
#
# <span style="align:left; text-align:center;">Kot lahko opazimo iz grafa, število hospitaliziranih oseb narašča kadar naraščajo okužbe, vendar v zadnjem valu lahko vidimo, da število hospitaliziranih oseb ni tako zelo veliko v primerjavi s številom okužb, saj je bila najbolj razširjena različica Omicron, ki ni tako močna, pravtako pa je bilo že veliko ljudi cepljenih.</span>
# </div>
#
# ## 2.2 Koliko jih je v intenzivni glede na hospitalizirane osebe?
#
# <div style="display: flex; align-items: center">
# <img src="https://media4.giphy.com/media/feP0faKTehLA93yhFU/giphy.gif?cid=790b76117e13f9ed6a477a2bff16cbdf4e4360d21aa0edaf&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
#
# <span style="align:left; text-align:center;">Naslednje kar nas je zanimalo pa je bilo, koliko od hospitaliziranih oseb je pravzaprav na intenzivni negi oz. v kritičnem stanju.</span>
# </div>
#
# <img src="podatki/images/graphs/g8.png" />
#
# **ODGOVOR**
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
#
# <span style="align:left; text-align:center;">Iz grafov se vidi, da je kritičnih kar dosti, a v primerjavi z vsemi primeri ne toliko. V bolnišnicah jih je največ v jesenskem in zimskem obdobju, poleti pa dosti manj, saj je bolj toplo in je imunski sistem pri večini bolj odporen.</span>
# </div>
#
# # 3. koliko jih je umrlo skozi čas (kdaj največ itd.)
#
# <img src="podatki/images/graphs/g9.png" />
# <img src="podatki/images/graphs/g10.png" />
#
# **ODGOVOR**
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
# <span style="align:left; text-align:left;">V celotnem obdobju COVID-19 je do izdelave tega poročila umrlo 6626 ljudi. To je     0.6% vseh potrjenih primerov okužb (1021139 primerov).</span>
# </div>
#
# # 4. koliko okužb glede na letni čas?
#
# <img src="podatki/images/graphs/g11.png" />
#
# **ODGOVOR**
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
# <span style="align:left; text-align:left;">Iz grafa je razvidno, da je vsako zimo največ okužb. Spomladi okužbe začnejo padati in nehajo padati poleti, nato pa spet začnejo rasti proti jeseni. Okužb je bilo vsako zimo več, saj se je virus čez leta bolj razširil.</span>
# </div>
#
# # 5. presežene smrti po letih
#
# <img src="podatki/images/graphs/g12.png" />
# <img src="podatki/images/graphs/g13.png" />
# <img src="podatki/images/graphs/g14.png" />
#
# **ODGOVOR**
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
# <span style="align:left; text-align:left;">Na grafih lahko vidimo povprečno število smrti vsak mesec med leti 2015-2019 v primerjavi z leti 2020 in 2021 ter povprečjem 2020-2021. Kot vidimo, se v Covid obdobju številka predvsem jeseni in pozimi dosti dvigne, največje mesečno odstopanje pa je skoraj 1200 smrti.</span>
# </div>
#
# # 6. Obarvana slovenija
#
# <img src="podatki/images/result.gif" />
#
# <div style="display: flex;">
# <img src="https://i.imgur.com/y7YuMUZ.png" alt="drawing" width="150" height="500" style="display: block; margin-right: 10px;"/>
# <span style="align:left; text-align: left;">Odločili smo se, da naredimo obarvanost občin glede na število okuženih na 100K prebivalcev glede na občino
# (Če bi imela določena občina 100K prebivalcev, koliko od teh bi bilo okuženih).</br>
# Kot lahko vidimo, se iz začetka zemljevid počasi obarva iz zelene proti rdeči barvi in se med vsakim poletjem nekoliko nevtralizira proti rumenim/zelenim barvam, nato pa jeseni in pozimi število okužb narašča. Letošnjo zimo se je zgodila največja špica, zaradi katere je število okužb tudi drastično padlo, saj je covid-19 prebolelo veliko število ljudi in se je "zaščitenost" povečala, hkrati pa se je zima počasi bližala pomladi, ko okužbe začnejo padati.</span>
# </div>
#
# # 7. Virus v odpadnih vodah
#
# <img src="podatki/images/graphs/g15.png" />
# <img src="podatki/images/graphs/g16.png" />
#
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
# <span style="align:left; text-align:left;">Iz grafa je razvidno, da je število okuženih in količina virusa v odpadnih vodah tudi malo korelativna. V odpadnih vodah je virus predvsem zaradi tega, ker pride voda v kontakt z okuženo osebo.</span>
# </div>
#
# # 8. Hospitaliziacije - status cepljenja in starost
#
# <img src="podatki/images/graphs/g17.png" />
#
# **ODGOVOR**
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
# <span style="align:left; text-align:left;">Iz grafa je razvidno, da je tistih, ki so cepljeni v bolnišnicah manj kot tistih, ki niso. Cepivo prepreči hujše oblike bolezni.</span>
# </div>
#
# # Zaključek
# <div style="display: flex; align-items: center">
# <img src="https://media0.giphy.com/media/gH94kBTHmFum6aMYzu/giphy.gif?cid=ecf05e479ewwdhf3b5fno334ubolhamx30j6pdhwph1wq0b9&rid=giphy.gif&ct=s" alt="drawing" width="100" height="100" style="display: block; margin-right: 10px;"/>
# <span style="align:left; text-align:left;">Ugotovili smo:</br>
#
# Da virus skoz čas mutira in postaja bolj odporen, kljub temu pa
#   postaja manj nevaren (primer: omicron).</br></br>
#
# Da zaščitenost in število okužb ni v direktni korelaciji. Razlogov je več, prvi je
#   ta, da so cepljene osebe lahko še vedno kužne, drugi pa, da se ne cepijo vsi in je učinek cepiv manjši.</br></br>
#
# Da je bilo glede na število okužb od teh dosti manj tudi v bolnišnici.</br></br>
#
# Skozi čas je umrlo 0,6% (6626) vseh primerov okužb (1021139).
# </br></br>
#
# Največ okužb je bilo jeseni in pozimi, spomladi in poleti pa število okužb pada.</br></br>
#
# Količina virusa v odpadnih vodah je korelativna s številom okužb.</span>
# </div>
